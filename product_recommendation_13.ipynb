# %%
import numpy as np 
import pandas as pd 
from mlxtend.frequent_patterns import apriori, association_rules 
from matplotlib import pyplot as plt

# %% [markdown]
# ### 1. Data Collection

# %%
# Loading the Data 
data = pd.read_excel('online_retail.xlsx') 
data.head()
print(f"Shape of data after removing missing values: {data.shape}")
# Out:
# Shape of data after removing missing values: (525461, 8)

# %%
# Amount of Data
data.__len__()
# Out:
# 525461

# %%
# Explore the Backgorund of the Data
data.columns
print("unqiue country: ", data.Country.unique())
print("Counties: ", data.Country.unique().__len__())
# Out:
# unqiue country:  ['United Kingdom' 'France' 'USA' 'Belgium' 'Australia' 'EIRE' 'Germany'
#  'Portugal' 'Japan' 'Denmark' 'Nigeria' 'Netherlands' 'Poland' 'Spain'
#  'Channel Islands' 'Italy' 'Cyprus' 'Greece' 'Norway' 'Austria' 'Sweden'
#  'United Arab Emirates' 'Finland' 'Switzerland' 'Unspecified' 'Malta'
#  'Bahrain' 'RSA' 'Bermuda' 'Hong Kong' 'Singapore' 'Thailand' 'Israel'
#  'Lithuania' 'West Indies' 'Lebanon' 'Korea' 'Brazil' 'Canada' 'Iceland']
# Counties:  40

# %% [markdown]
# ### 2. Data Processing

# %%
# Handle missing values appropriately
# Remove missing values
required_columns = ['Invoice', 'StockCode', 'Quantity', 'Description', 'Customer ID']
data_cleaned = data.dropna(subset=required_columns)
print("Data after removing missing values:")
print(data_cleaned.head())  # Display the first few rows
print(f"Shape of data after removing missing values: {data_cleaned.shape}")
print(f"Size of data after removing missing values: {len(data_cleaned)}")
# Out:
# Data after removing missing values:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#           InvoiceDate  Price  Customer ID         Country
# 0 2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3 2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4 2009-12-01 07:45:00   1.25      13085.0  United Kingdom
# Shape of data after removing missing values: (417534, 8)
# Size of data after removing missing values: 417534

# %%
# Filter out negative quantities from the DataFrame
data_cleaned = data_cleaned[data_cleaned['Quantity'] > 0]
print("Data after filtering out negative quantities:")
print(data_cleaned.head())  # Display the first few rows
print(f"Shape of data after filtering negative quantities: {data_cleaned.shape}")
print(f"Size of data after filtering negative quantities: {len(data_cleaned)}")
# Out:
# Data after filtering out negative quantities:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#           InvoiceDate  Price  Customer ID         Country
# 0 2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3 2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4 2009-12-01 07:45:00   1.25      13085.0  United Kingdom
# Shape of data after filtering negative quantities: (407695, 8)
# Size of data after filtering negative quantities: 407695

# %%
# Remove canceled invoices from the DataFrame
data_cleaned = data_cleaned[~data_cleaned['Invoice'].astype(str).str.contains('C', na=False)]
print("Data after removing canceled invoices:")
print(data_cleaned.head())  # Display the first few rows
print(f"Shape of data after removing canceled invoices: {data_cleaned.shape}")
print(f"Size of data after removing canceled invoices: {len(data_cleaned)}")
# Out:
# Data after removing canceled invoices:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#           InvoiceDate  Price  Customer ID         Country
# 0 2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3 2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4 2009-12-01 07:45:00   1.25      13085.0  United Kingdom
# Shape of data after removing canceled invoices: (407695, 8)
# Size of data after removing canceled invoices: 407695

# %% [markdown]
# ### 3. Create a basket

# %%
# Create a basket by grouping by 'Invoice' and concatenating descriptions
basket = data_cleaned.groupby('Invoice')['Description'].apply(lambda x: ', '.join(x)).reset_index()
print("Basket created:")
print(basket.head())  # Display the first few rows of the basket
print(f"Shape of basket: {basket.shape}")
# Out:
# Basket created:
#    Invoice                                        Description
# 0   489434  15CM CHRISTMAS GLASS BALL 20 LIGHTS, PINK CHER...
# 1   489435  CAT BOWL , DOG BOWL , CHASING BALL DESIGN, HEA...
# 2   489436  DOOR MAT BLACK FLOCK , LOVE BUILDING BLOCK WOR...
# 3   489437  CHRISTMAS CRAFT HEART DECORATIONS, CHRISTMAS C...
# 4   489438  DINOSAURS  WRITING SET , SET OF MEADOW  FLOWER...
# Shape of basket: (19215, 2)

# %% [markdown]
# ### 4. One-hot Encoding

# %%
from mlxtend.preprocessing import TransactionEncoder

# Create a list of transactions (split descriptions into lists)
transactions = basket['Description'].str.split(', ').tolist()

# Perform one-hot encoding
te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)
df_onehot = pd.DataFrame(te_ary, columns=te.columns_)

# Display the one-hot encoded DataFrame
print("One-Hot Encoded DataFrame:")
print(df_onehot.head())
# Out:
# One-Hot Encoded DataFrame:
#             DOORMAT UNION JACK GUNS AND ROSES   3 STRIPEY MICE FELTCRAFT  \
# 0  False                                False                      False
# 1  False                                False                      False
# 2  False                                False                      False
# 3  False                                False                      False
# 4  False                                False                      False
#
#     4 PURPLE FLOCK DINNER CANDLES   ANIMAL STICKERS  \
# 0                           False             False
# 1                           False             False
# 2                           False             False
# 3                           False             False
# 4                           False             False
#
#     BLACK PIRATE TREASURE CHEST   BROWN  PIRATE TREASURE CHEST   \
# 0                         False                           False
# 1                         False                           False
# 2                         False                           False
# 3                         False                           False
# 4                         False                           False
#
#     Bank Charges   CAMPHOR WOOD PORTOBELLO MUSHROOM  \
# 0          False                              False
# 1          False                              False
# 2          False                              False
# 3          False                              False
# 4          False                              False
#
#     CHERRY BLOSSOM  DECORATIVE FLASK  ...  ZINC HEART LATTICE CHARGER LARGE  \
# 0                              False  ...                             False
# 1                              False  ...                             False
# 2                              False  ...                             False
# 3                              False  ...                             False
# 4                              False  ...                             False
#
#    ZINC HEART LATTICE CHARGER SMALL  ZINC HEART LATTICE DOUBLE PLANTER  \
# 0                             False                              False
# 1                             False                              False
# 2                             False                              False
# 3                             False                              False
# 4                             False                              False
#
#    ZINC HEART LATTICE PLANTER BOWL  ZINC HEART LATTICE T-LIGHT HOLDER  \
# 0                            False                              False
# 1                            False                              False
# 2                            False                              False
# 3                            False                              False
# 4                            False                              False
#
#    ZINC HEART LATTICE TRAY OVAL   ZINC METAL HEART DECORATION  \
# 0                          False                        False
# 1                          False                        False
# 2                          False                        False
# 3                          False                        False
# 4                          False                        False
#
#    ZINC POLICE BOX LANTERN  ZINC TOP  2 DOOR WOODEN SHELF   \
# 0                    False                           False
# 1                    False                           False
# 2                    False                           False
# 3                    False                           False
# 4                    False                           False
#
#    ZINC WILLIE WINKIE  CANDLE STICK
# 0                             False
# 1                             False
# 2                             False
# 3                             False
# 4                             False
#
# [5 rows x 4487 columns]

# %% [markdown]
# ### 5. Implementation of Apriori Algorithm

# %%
from mlxtend.frequent_patterns import apriori, association_rules

# Apply Apriori Algorithm
frequent_itemsets = apriori(df_onehot, min_support=0.01, use_colnames=True)
print("Frequent Itemsets:")
print(frequent_itemsets.head())  # Display the first few frequent itemsets
# Out:
# Frequent Itemsets:
#     support                         itemsets
# 0  0.030965                               ()
# 1  0.011189           ( WHITE CHERRY LIGHTS)
# 2  0.011501         (1 HANGER ,MAGIC GARDEN)
# 3  0.012855         (10 COLOUR SPACEBOY PEN)
# 4  0.013063  (12 PENCIL SMALL TUBE WOODLAND)

# %% [markdown]
# ### 6. Assosiation Rules Generation

# %%
# Generate Association Rules
# Generate association rules from the frequent itemsets
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1, num_itemsets=len(frequent_itemsets))
print("Association Rules:")
print(rules.head())  # Display the first few association rules
# Out:
# Association Rules:
#        antecedents                 consequents  antecedent support  \
# 0               ()             (BIRTHDAY CARD)            0.030965
# 1  (BIRTHDAY CARD)                          ()            0.016185
# 2               ()                  (ELEPHANT)            0.030965
# 3       (ELEPHANT)                          ()            0.014260
# 4               ()  (FANCY FONT BIRTHDAY CARD)            0.030965
#
#    consequent support   support  confidence       lift  representativity  \
# 0            0.016185  0.014676    0.473950  29.282769               1.0
# 1            0.030965  0.014676    0.906752  29.282769               1.0
# 2            0.014260  0.014260    0.460504  32.294118               1.0
# 3            0.030965  0.014260    1.000000  32.294118               1.0
# 4            0.016081  0.016081    0.519328  32.294118               1.0
#
#    leverage  conviction  zhangs_metric   jaccard  certainty  kulczynski
# 0  0.014175    1.870191       0.996714  0.451923   0.465295    0.690351
# 1  0.014175   10.392061       0.981740  0.451923   0.903773    0.690351
# 2  0.013818    1.827151       1.000000  0.460504   0.452700    0.730252
# 3  0.013818         inf       0.983053  0.460504   1.000000    0.730252
# 4  0.015583    2.046964       1.000000  0.519328   0.511472    0.759664

# %% [markdown]
# ### 7. Function to Recommend Products

# %%
# just Experiment
# Function to Recommend Products
def recommend_products(product_name):
    # Check for the product name in the antecedents using a case-insensitive search
    product_rules = rules[rules['antecedents'].apply(lambda x: any(product_name.lower() == str(item).lower() for item in x))]
    
    if product_rules.empty:
        return f"No recommendations found for '{product_name}'."
    
    recommended = product_rules['consequents'].apply(lambda x: list(x)[0])
    return recommended.tolist()

# Example usage
product_to_check = 'STRAWBERRY CERAMIC TRINKET BOX'  # Ensure this matches a product in your dataset
recommended_products = recommend_products(product_to_check)

# Print the recommendations
print(f"Products recommended for '{product_to_check}': {recommended_products}")

# Function to print the rules associated with a given product
def print_recommendation_proof(product_name):
    # Find rules where the product is an antecedent
    relevant_rules = rules[rules['antecedents'].apply(lambda x: product_name in x)]
    
    if relevant_rules.empty:
        print(f"No rules found for '{product_name}'.")
        return
    
    print(f"Rules for '{product_name}':")
    for index, row in relevant_rules.iterrows():
        antecedents = ', '.join(list(row['antecedents']))
        consequents = ', '.join(list(row['consequents']))
        support = row['support']
        confidence = row['confidence']
        lift = row['lift']
        
        print(f" - If you buy: {antecedents}, then you may also buy: {consequents}. (Support: {support:.2f}, Confidence: {confidence:.2f}, Lift: {lift:.2f})")

# Print the proof for the recommendations
print_recommendation_proof(product_to_check)
# Out:
# Products recommended for 'STRAWBERRY CERAMIC TRINKET BOX': ['60 TEATIME FAIRY CAKE CASES', 'PINK DOUGHNUT TRINKET POT ', 'SWEETHEART CERAMIC TRINKET BOX', 'WHITE HANGING HEART T-LIGHT HOLDER']
# Rules for 'STRAWBERRY CERAMIC TRINKET BOX':
#  - If you buy: STRAWBERRY CERAMIC TRINKET BOX, then you may also buy: 60 TEATIME FAIRY CAKE CASES. (Support: 0.01, Confidence: 0.17, Lift: 2.83)
#  - If you buy: STRAWBERRY CERAMIC TRINKET BOX, then you may also buy: PINK DOUGHNUT TRINKET POT . (Support: 0.01, Confidence: 0.15, Lift: 8.88)
#  - If you buy: STRAWBERRY CERAMIC TRINKET BOX, then you may also buy: SWEETHEART CERAMIC TRINKET BOX. (Support: 0.03, Confidence: 0.47, Lift: 11.08)
#  - If you buy: STRAWBERRY CERAMIC TRINKET BOX, then you may also buy: WHITE HANGING HEART T-LIGHT HOLDER. (Support: 0.02, Confidence: 0.26, Lift: 1.62)

# %%
# Test with Various Items
# Function to recommend products
def recommend_products(product_name):
    # Check for the product name in the antecedents using a case-insensitive search
    product_rules = rules[rules['antecedents'].apply(lambda x: any(product_name.lower() == str(item).lower() for item in x))]
    
    if product_rules.empty:
        return f"No recommendations found for '{product_name}'."
    
    recommended = product_rules['consequents'].apply(lambda x: list(x)[0])
    return recommended.tolist()

# Function to print the rules associated with a given product
def print_recommendation_proof(product_name):
    # Find rules where the product is an antecedent
    relevant_rules = rules[rules['antecedents'].apply(lambda x: product_name in x)]
    
    if relevant_rules.empty:
        print(f"No rules found for '{product_name}'.")
        return
    
    print(f"Rules for '{product_name}':")
    for index, row in relevant_rules.iterrows():
        antecedents = ', '.join(list(row['antecedents']))
        consequents = ', '.join(list(row['consequents']))
        support = row['support']
        confidence = row['confidence']
        lift = row['lift']
        
        print(f" - If you buy: {antecedents}, then you may also buy: {consequents}. (Support: {support:.2f}, Confidence: {confidence:.2f}, Lift: {lift:.2f})")

# List of products to check
test_items = [
    "WHITE HANGING HEART T-LIGHT HOLDER",
    "WHITE METAL LANTERN",
    "CREAM CUPID HEARTS COAT HANGER",
    "KNITTED UNION FLAG HOT WATER BOTTLE",
    "RED WOOLLY HOTTIE WHITE HEART.",
    "SET 7 BABUSHKA NESTING BOXES",
    "GLASS STAR FROSTED T-LIGHT HOLDER",
    "HAND WARMER UNION JACK",
    "HAND WARMER RED POLKA DOT",
    "JAM MAKING SET WITH JARS",
    "RED COAT RACK PARIS FASHION",
    "YELLOW COAT RACK PARIS FASHION",
    "BLUE COAT RACK PARIS FASHION",
    "ASSORTED COLOUR BIRD ORNAMENT",
    "POPPY'S PLAYHOUSE BEDROOM",
    "POPPY'S PLAYHOUSE KITCHEN",
    "FELTCRAFT PRINCESS CHARLOTTE DOLL",
    "IVORY KNITTED MUG COSY",
    "BOX OF 6 ASSORTED COLOUR TEASPOONS",
    "BOX OF VINTAGE JIGSAW BLOCKS",
    "BOX OF VINTAGE ALPHABET BLOCKS",
    "HOME BUILDING BLOCK WORD",
    "LOVE BUILDING BLOCK WORD",
    "RECIPE BOX WITH METAL HEART",
    "DOORMAT NEW ENGLAND",
    "BATH BUILDING BLOCK WORD",
    "ALARM CLOCK BAKELIKE PINK",
    "ALARM CLOCK BAKELIKE RED",
    "ALARM CLOCK BAKELIKE GREEN",
    "PANDA AND BUNNIES STICKER SHEET",
    "STARS GIFT TAPE",
    "INFLATABLE POLITICAL GLOBE",
    "VINTAGE HEADS AND TAILS CARD GAME",
    "SET/2 RED RETROSPOT TEA TOWELS",
    "ROUND SNACK BOXES SET OF4 WOODLAND",
    "SPACEBOY LUNCH BOX",
    "LUNCH BOX I LOVE LONDON",
    "CIRCUS PARADE LUNCH BOX",
    "CHARLOTTE BAG DOLLY GIRL DESIGN",
    "RED TOADSTOOL LED NIGHT LIGHT",
    "SET 2 TEA TOWELS I LOVE LONDON",
    "VINTAGE SEASIDE JIGSAW PUZZLES",
    "MINI JIGSAW CIRCUS PARADE",
    "MINI JIGSAW SPACEBOY",
    "MINI PAINT SET VINTAGE",
    "POSTAGE",
    "PAPER CHAIN KIT 50'S CHRISTMAS",
    "HAND WARMER RED POLKA DOT",
    "HAND WARMER UNION JACK",
    "WHITE HANGING HEART T-LIGHT HOLDER",
    "WHITE METAL LANTERN",
    "CREAM CUPID HEARTS COAT HANGER",
    "EDWARDIAN PARASOL RED",
    "RETRO COFFEE MUGS ASSORTED",
    "SAVE THE PLANET MUG",
    "VINTAGE BILLBOARD DRINK ME MUG",
    "VINTAGE BILLBOARD LOVE/HATE MUG",
    "WOOD 2 DRAWER CABINET WHITE FINISH",
    "WOOD S/3 CABINET ANT WHITE FINISH",
    "WOODEN PICTURE FRAME WHITE FINISH",
]

# Loop through the test items and display recommendations
for product_to_check in test_items:
    print(f"\nChecking recommendations for: {product_to_check}")
    recommended_products = recommend_products(product_to_check)
    print(f"Products recommended for '{product_to_check}': {recommended_products}")
    print_recommendation_proof(product_to_check)
# Out:
# Checking recommendations for: WHITE HANGING HEART T-LIGHT HOLDER
# Products recommended for 'WHITE HANGING HEART T-LIGHT HOLDER': ['60 TEATIME FAIRY CAKE CASES', 'ASSORTED COLOUR BIRD ORNAMENT', 'CHOCOLATE HOT WATER BOTTLE', 'COOK WITH WINE METAL SIGN ', 'CREAM CUPID HEARTS COAT HANGER', 'CREAM HEART CARD HOLDER', 'GIN + TONIC DIET METAL SIGN', 'HAND OVER THE CHOCOLATE   SIGN ', 'HANGING HEART ZINC T-LIGHT HOLDER', 'HEART FILIGREE DOVE  SMALL', 'HEART FILIGREE DOVE LARGE', 'HEART IVORY TRELLIS LARGE', 'HEART OF WICKER LARGE', 'HEART OF WICKER SMALL', 'HOME BUILDING BLOCK WORD', 'JUMBO BAG RED RETROSPOT', 'JUMBO BAG STRAWBERRY', 'LOVE BUILDING BLOCK WORD', 'LUNCH BAG  BLACK SKULL.', 'LUNCH BAG CARS BLUE', 'LUNCH BAG RED SPOTTY', 'LUNCH BAG SUKI  DESIGN ', 'NATURAL SLATE HEART CHALKBOARD ', 'PACK OF 72 RETRO SPOT CAKE CASES', 'PLEASE ONE PERSON METAL SIGN', 'RED HANGING HEART T-LIGHT HOLDER', 'RED WOOLLY HOTTIE WHITE HEART.', 'REGENCY CAKESTAND 3 TIER', 'REX CASH+CARRY JUMBO SHOPPER', 'SCOTTIE DOG HOT WATER BOTTLE', 'STRAWBERRY CERAMIC TRINKET BOX', 'SWEETHEART CERAMIC TRINKET BOX', 'VICTORIAN GLASS HANGING T-LIGHT', 'VINTAGE UNION JACK BUNTING', 'WOOD 2 DRAWER CABINET WHITE FINISH', 'WOOD S/3 CABINET ANT WHITE FINISH', 'WOODEN FRAME ANTIQUE WHITE ', 'WOODEN PICTURE FRAME WHITE FINISH', 'ZINC METAL HEART DECORATION', 'HEART OF WICKER LARGE', 'HEART OF WICKER SMALL', 'HEART OF WICKER SMALL', 'WOODEN FRAME ANTIQUE WHITE ', 'WOODEN PICTURE FRAME WHITE FINISH', 'WOODEN PICTURE FRAME WHITE FINISH']
# Rules for 'WHITE HANGING HEART T-LIGHT HOLDER':
#  - If you buy: WHITE HANGING HEART T-LIGHT HOLDER, then you may also buy
#  - If you buy: ASSORTED COLOUR BIRD ORNAMENT, then you may also buy: HOME BUILDING BLOCK WORD. (Support: 0.01, Confidence: 0.16, Lift: 2.66)
#  - If you buy: ASSORTED COLOUR BIRD ORNAMENT, then you may also buy: PAINTED METAL PEARS ASSORTED. (Support: 0.01, Confidence: 0.21, Lift: 10.69)
#  - If you buy: ASSORTED COLOUR BIRD ORNAMENT, then you may also buy: WHITE HANGING HEART T-LIGHT HOLDER. (Support: 0.02, Confidence: 0.29, Lift: 1.86)
#
# Checking recommendations for: POPPY'S PLAYHOUSE BEDROOM
# Products recommended for 'POPPY'S PLAYHOUSE BEDROOM': No recommendations found for 'POPPY'S PLAYHOUSE BEDROOM'.
# No rules found for 'POPPY'S PLAYHOUSE BEDROOM'.
#
# Checking recommendations for: POPPY'S PLAYHOUSE KITCHEN
# Products recommended for 'POPPY'S PLAYHOUSE KITCHEN': ["POPPY'S PLAYHOUSE BEDROOM ", "POPPY'S PLAYHOUSE LIVINGROOM "]
# Rules for 'POPPY'S PLAYHOUSE KITCHEN':
#  - If you buy: POPPY'S PLAYHOUSE KITCHEN, then you may also buy: POPPY'S PLAYHOUSE BEDROOM . (Support: 0.01, Confidence: 0.81, Lift: 57.84)
#  - If you buy: POPPY'S PLAYHOUSE KITCHEN, then you may also buy: POPPY'S PLAYHOUSE LIVINGROOM . (Support: 0.01, Confidence: 0.71, Lift: 59.49)
#
# Checking recommendations for: FELTCRAFT PRINCESS CHARLOTTE DOLL
# Products recommended for 'FELTCRAFT PRINCESS CHARLOTTE DOLL': No recommendations found for 'FELTCRAFT PRINCESS CHARLOTTE DOLL'.
# No rules found for 'FELTCRAFT PRINCESS CHARLOTTE DOLL'.
#
# Checking recommendations for: IVORY KNITTED MUG COSY
# Products recommended for 'IVORY KNITTED MUG COSY': No recommendations found for 'IVORY KNITTED MUG COSY'.
# No rules found for 'IVORY KNITTED MUG COSY'.
#
# Checking recommendations for: BOX OF 6 ASSORTED COLOUR TEASPOONS
# Products recommended for 'BOX OF 6 ASSORTED COLOUR TEASPOONS': No recommendations found for 'BOX OF 6 ASSORTED COLOUR TEASPOONS'.
# No rules found for 'BOX OF 6 ASSORTED COLOUR TEASPOONS'.
#
# Checking recommendations for: BOX OF VINTAGE JIGSAW BLOCKS
# Products recommended for 'BOX OF VINTAGE JIGSAW BLOCKS': No recommendations found for 'BOX OF VINTAGE JIGSAW BLOCKS'.
# No rules found for 'BOX OF VINTAGE JIGSAW BLOCKS'.
#
# Checking recommendations for: BOX OF VINTAGE ALPHABET BLOCKS
# Products recommended for 'BOX OF VINTAGE ALPHABET BLOCKS': No recommendations found for 'BOX OF VINTAGE ALPHABET BLOCKS'.
# No rules found for 'BOX OF VINTAGE ALPHABET BLOCKS'.
#
# Checking recommendations for: HOME BUILDING BLOCK WORD
# Products recommended for 'HOME BUILDING BLOCK WORD': ['ASSORTED COLOUR BIRD ORNAMENT', 'LOVE BUILDING BLOCK WORD', 'WHITE HANGING HEART T-LIGHT HOLDER']
# Rules for 'HOME BUILDING BLOCK WORD':
#  - If you buy: HOME BUILDING BLOCK WORD, then you may also buy: ASSORTED COLOUR BIRD ORNAMENT. (Support: 0.01, Confidence: 0.18, Lift: 2.66)
#  - If you buy: HOME BUILDING BLOCK WORD, then you may also buy: LOVE BUILDING BLOCK WORD. (Support: 0.03, Confidence: 0.44, Lift: 9.00)
#  - If you buy: HOME BUILDING BLOCK WORD, then you may also buy: WHITE HANGING HEART T-LIGHT HOLDER. (Support: 0.02, Confidence: 0.33, Lift: 2.12)
#
# Checking recommendations for: LOVE BUILDING BLOCK WORD
# Products recommended for 'LOVE BUILDING BLOCK WORD': ['HOME BUILDING BLOCK WORD', 'WHITE HANGING HEART T-LIGHT HOLDER']
# Rules for 'LOVE BUILDING BLOCK WORD':
#  - If you buy: LOVE BUILDING BLOCK WORD, then you may also buy: HOME BUILDING BLOCK WORD. (Support: 0.03, Confidence: 0.55, Lift: 9.00)
#  - If you buy: LOVE BUILDING BLOCK WORD, then you may also buy: WHITE HANGING HEART T-LIGHT HOLDER. (Support: 0.02, Confidence: 0.39, Lift: 2.48)
#
# Checking recommendations for: RECIPE BOX WITH METAL HEART
# Products recommended for 'RECIPE BOX WITH METAL HEART': No recommendations found for 'RECIPE BOX WITH METAL HEART'.
# No rules found for 'RECIPE BOX WITH METAL HEART'.
#
# Checking recommendations for: DOORMAT NEW ENGLAND
# Products recommended for 'DOORMAT NEW ENGLAND': No recommendations found for 'DOORMAT NEW ENGLAND'.
# No rules found for 'DOORMAT NEW ENGLAND'.
#
# Checking recommendations for: BATH BUILDING BLOCK WORD
# Products recommended for 'BATH BUILDING BLOCK WORD': No recommendations found for 'BATH BUILDING BLOCK WORD'.
# No rules found for 'BATH BUILDING BLOCK WORD'.
#
# Checking recommendations for: ALARM CLOCK BAKELIKE PINK
# Products recommended for 'ALARM CLOCK BAKELIKE PINK': No recommendations found for 'ALARM CLOCK BAKELIKE PINK'.
# No rules found for 'ALARM CLOCK BAKELIKE PINK'.
#
# Checking recommendations for: ALARM CLOCK BAKELIKE RED
# Products recommended for 'ALARM CLOCK BAKELIKE RED': No recommendations found for 'ALARM CLOCK BAKELIKE RED'.
# No rules found for 'ALARM CLOCK BAKELIKE RED'.
#
# Checking recommendations for: ALARM CLOCK BAKELIKE GREEN
# Products recommended for 'ALARM CLOCK BAKELIKE GREEN': ['ALARM CLOCK BAKELIKE RED ']
# Rules for 'ALARM CLOCK BAKELIKE GREEN':
#  - If you buy: ALARM CLOCK BAKELIKE GREEN, then you may also buy: ALARM CLOCK BAKELIKE RED . (Support: 0.01, Confidence: 0.68, Lift: 42.78)
#
# Checking recommendations for: PANDA AND BUNNIES STICKER SHEET
# Products recommended for 'PANDA AND BUNNIES STICKER SHEET': No recommendations found for 'PANDA AND BUNNIES STICKER SHEET'.
# No rules found for 'PANDA AND BUNNIES STICKER SHEET'.
#
# Checking recommendations for: STARS GIFT TAPE
# Products recommended for 'STARS GIFT TAPE': No recommendations found for 'STARS GIFT TAPE'.
# No rules found for 'STARS GIFT TAPE'.
#
# Checking recommendations for: INFLATABLE POLITICAL GLOBE
# Products recommended for 'INFLATABLE POLITICAL GLOBE': No recommendations found for 'INFLATABLE POLITICAL GLOBE'.
# No rules found for 'INFLATABLE POLITICAL GLOBE'.
#
# Checking recommendations for: VINTAGE HEADS AND TAILS CARD GAME
# Products recommended for 'VINTAGE HEADS AND TAILS CARD GAME': No recommendations found for 'VINTAGE HEADS AND TAILS CARD GAME'.
# No rules found for 'VINTAGE HEADS AND TAILS CARD GAME'.
#
# Checking recommendations for: SET/2 RED RETROSPOT TEA TOWELS
# Products recommended for 'SET/2 RED RETROSPOT TEA TOWELS': No recommendations found for 'SET/2 RED RETROSPOT TEA TOWELS'.
# No rules found for 'SET/2 RED RETROSPOT TEA TOWELS'.
#
# Checking recommendations for: ROUND SNACK BOXES SET OF4 WOODLAND
# Products recommended for 'ROUND SNACK BOXES SET OF4 WOODLAND': No recommendations found for 'ROUND SNACK BOXES SET OF4 WOODLAND'.
# No rules found for 'ROUND SNACK BOXES SET OF4 WOODLAND'.
#
# Checking recommendations for: SPACEBOY LUNCH BOX
# Products recommended for 'SPACEBOY LUNCH BOX': No recommendations found for 'SPACEBOY LUNCH BOX'.
# No rules found for 'SPACEBOY LUNCH BOX'.
#
# Checking recommendations for: LUNCH BOX I LOVE LONDON
# Products recommended for 'LUNCH BOX I LOVE LONDON': No recommendations found for 'LUNCH BOX I LOVE LONDON'.
# No rules found for 'LUNCH BOX I LOVE LONDON'.
#
# Checking recommendations for: CIRCUS PARADE LUNCH BOX
# Products recommended for 'CIRCUS PARADE LUNCH BOX': No recommendations found for 'CIRCUS PARADE LUNCH BOX'.
# No rules found for 'CIRCUS PARADE LUNCH BOX'.
#
# Checking recommendations for: CHARLOTTE BAG DOLLY GIRL DESIGN
# Products recommended for 'CHARLOTTE BAG DOLLY GIRL DESIGN': No recommendations found for 'CHARLOTTE BAG DOLLY GIRL DESIGN'.
# No rules found for 'CHARLOTTE BAG DOLLY GIRL DESIGN'.
#
# Checking recommendations for: RED TOADSTOOL LED NIGHT LIGHT
# Products recommended for 'RED TOADSTOOL LED NIGHT LIGHT': No recommendations found for 'RED TOADSTOOL LED NIGHT LIGHT'.
# No rules found for 'RED TOADSTOOL LED NIGHT LIGHT'.
#
# Checking recommendations for: SET 2 TEA TOWELS I LOVE LONDON
# Products recommended for 'SET 2 TEA TOWELS I LOVE LONDON': No recommendations found for 'SET 2 TEA TOWELS I LOVE LONDON'.
# No rules found for 'SET 2 TEA TOWELS I LOVE LONDON'.
#
# Checking recommendations for: VINTAGE SEASIDE JIGSAW PUZZLES
# Products recommended for 'VINTAGE SEASIDE JIGSAW PUZZLES': No recommendations found for 'VINTAGE SEASIDE JIGSAW PUZZLES'.
# No rules found for 'VINTAGE SEASIDE JIGSAW PUZZLES'.
#
# Checking recommendations for: MINI JIGSAW CIRCUS PARADE
# Products recommended for 'MINI JIGSAW CIRCUS PARADE': No recommendations found for 'MINI JIGSAW CIRCUS PARADE'.
# No rules found for 'MINI JIGSAW CIRCUS PARADE'.
#
# Checking recommendations for: MINI JIGSAW SPACEBOY
# Products recommended for 'MINI JIGSAW SPACEBOY': No recommendations found for 'MINI JIGSAW SPACEBOY'.
# No rules found for 'MINI JIGSAW SPACEBOY'.
#
# Checking recommendations for: MINI PAINT SET VINTAGE
# Products recommended for 'MINI PAINT SET VINTAGE': No recommendations found for 'MINI PAINT SET VINTAGE'.
# No rules found for 'MINI PAINT SET VINTAGE'.
#
# Checking recommendations for: POSTAGE
# Products recommended for 'POSTAGE': No recommendations found for 'POSTAGE'.
# No rules found for 'POSTAGE'.
#
# Checking recommendations for: PAPER CHAIN KIT 50'S CHRISTMAS
# Products recommended for 'PAPER CHAIN KIT 50'S CHRISTMAS': No recommendations found for 'PAPER CHAIN KIT 50'S CHRISTMAS'.
# No rules found for 'PAPER CHAIN KIT 50'S CHRISTMAS'.
#
# Checking recommendations for: HAND WARMER RED POLKA DOT
# Products recommended for 'HAND WARMER RED POLKA DOT': No recommendations found for 'HAND WARMER RED POLKA DOT'.
# No rules found for 'HAND WARMER RED POLKA DOT'.
#
# Checking recommendations for: HAND WARMER UNION JACK
# Products recommended for 'HAND WARMER UNION JACK': ['HAND WARMER OWL DESIGN', 'HAND WARMER RED RETROSPOT']
# Rules for 'HAND WARMER UNION JACK':
#  - If you buy: HAND WARMER UNION JACK, then you may also buy: HAND WARMER OWL DESIGN. (Support: 0.01, Confidence: 0.49, Lift: 17.09)
#  - If you buy: HAND WARMER UNION JACK, then you may also buy: HAND WARMER RED RETROSPOT. (Support: 0.01, Confidence: 0.46, Lift: 22.97)
#
# Checking recommendations for: WHITE HANGING HEART T-LIGHT HOLDER
# Products recommended for 'WHITE HANGING HEART T-LIGHT HOLDER': ['60 TEATIME FAIRY CAKE CASES', 'ASSORTED COLOUR BIRD ORNAMENT', 'CHOCOLATE HOT WATER BOTTLE', 'COOK WITH WINE METAL SIGN ', 'CREAM CUPID HEARTS COAT HANGER', 'CREAM HEART CARD HOLDER', 'GIN + TONIC DIET METAL SIGN', 'HAND OVER THE CHOCOLATE   SIGN ', 'HANGING HEART ZINC T-LIGHT HOLDER', 'HEART FILIGREE DOVE  SMALL', 'HEART FILIGREE DOVE LARGE', 'HEART IVORY TRELLIS LARGE', 'HEART OF WICKER LARGE', 'HEART OF WICKER SMALL', 'HOME BUILDING BLOCK WORD', 'JUMBO BAG RED RETROSPOT', 'JUMBO BAG STRAWBERRY', 'LOVE BUILDING BLOCK WORD', 'LUNCH BAG  BLACK SKULL.', 'LUNCH BAG CARS BLUE', 'LUNCH BAG RED SPOTTY', 'LUNCH BAG SUKI  DESIGN ', 'NATURAL SLATE HEART CHALKBOARD ', 'PACK OF 72 RETRO SPOT CAKE CASES', 'PLEASE ONE PERSON METAL SIGN', 'RED HANGING HEART T-LIGHT HOLDER', 'RED WOOLLY HOTTIE WHITE HEART.', 'REGENCY CAKESTAND 3 TIER', 'REX CASH+CARRY JUMBO SHOPPER', 'SCOTTIE DOG HOT WATER BOTTLE', 'STRAWBERRY CERAMIC TRINKET BOX', 'SWEETHEART CERAMIC TRINKET BOX', 'VICTORIAN GLASS HANGING T-LIGHT', 'VINTAGE UNION JACK BUNTING', 'WOOD 2 DRAWER CABINET WHITE FINISH', 'WOOD S/3 CABINET ANT WHITE FINISH', 'WOODEN FRAME ANTIQUE WHITE ', 'WOODEN PICTURE FRAME WHITE FINISH', 'ZINC METAL HEART DECORATION', 'HEART OF WICKER LARGE', 'HEART OF WICKER SMALL', 'HEART OF WICKER SMALL', 'WOODEN FRAME ANTIQUE WHITE ', 'WOODEN PICTURE FRAME WHITE FINISH', 'WOODEN PICTURE FRAME WHITE FINISH']
# Rules for 'WHITE HANGING HEART T-LIGHT HOLDER':
#  - If you buy: WHITE HANGING HEART T-LIGHT HOLDER, then you may also buy

#  - If you buy: WHITE HANGING HEART T-LIGHT HOLDER, then you may also buy: SCOTTIE DOG HOT WATER BOTTLE. (Support: 0.01, Confidence: 0.07, Lift: 1.66)
#  - If you buy: WHITE HANGING HEART T-LIGHT HOLDER, then you may also buy: STRAWBERRY CERAMIC TRINKET BOX. (Support: 0.02, Confidence: 0.11, Lift: 1.62)
#  - If you buy: WHITE HANGING HEART T-LIGHT HOLDER, then you may also buy: SWEETHEART CERAMIC TRINKET BOX. (Support: 0.01, Confidence: 0.07, Lift: 1.65)
#  - If you buy: WHITE HANGING HEART T-LIGHT HOLDER, then you may also buy: VICTORIAN GLASS HANGING T-LIGHT. (Support: 0.01, Confidence: 0.07, Lift: 2.01)
#  - If you buy: WHITE HANGING HEART T-LIGHT HOLDER, then you may also buy: VINTAGE UNION JACK BUNTING. (Support: 0.01, Confidence: 0.07, Lift: 1.83)
#  - If you buy: WHITE HANGING HEART T-LIGHT HOLDER, then you may also buy: WOOD 2 DRAWER CABINET WHITE FINISH. (Support: 0.01, Confidence: 0.09, Lift: 2.98)
#  - If you buy: WHITE HANGING HEART T-LIGHT HOLDER, then you may also buy: WOOD S/3 CABINET ANT WHITE FINISH. (Support: 0.01, Confidence: 0.09, Lift: 2.73)
#  - If you buy: WHITE HANGING HEART T-LIGHT HOLDER, then you may also buy: WOODEN FRAME ANTIQUE WHITE . (Support: 0.02, Confidence: 0.15, Lift: 2.79)
#  - If you buy: WHITE HANGING HEART T-LIGHT HOLDER, then you may also buy: WOODEN PICTURE FRAME WHITE FINISH. (Support: 0.02, Confidence: 0.13, Lift: 2.98)
#  - If you buy: WHITE HANGING HEART T-LIGHT HOLDER, then you may also buy: ZINC METAL HEART DECORATION. (Support: 0.02, Confidence: 0.11, Lift: 2.60)
#  - If you buy: HEART OF WICKER SMALL, WHITE HANGING HEART T-LIGHT HOLDER, then you may also buy: HEART OF WICKER LARGE. (Support: 0.01, Confidence: 0.62, Lift: 11.98)
#  - If you buy: HEART OF WICKER LARGE, WHITE HANGING HEART T-LIGHT HOLDER, then you may also buy: HEART OF WICKER SMALL. (Support: 0.01, Confidence: 0.52, Lift: 11.40)
#  - If you buy: WHITE HANGING HEART T-LIGHT HOLDER, then you may also buy: HEART OF WICKER SMALL, HEART OF WICKER LARGE. (Support: 0.01, Confidence: 0.07, Lift: 2.55)
#  - If you buy: WOODEN PICTURE FRAME WHITE FINISH, WHITE HANGING HEART T-LIGHT HOLDER, then you may also buy: WOODEN FRAME ANTIQUE WHITE . (Support: 0.01, Confidence: 0.72, Lift: 13.67)
#  - If you buy: WHITE HANGING HEART T-LIGHT HOLDER, WOODEN FRAME ANTIQUE WHITE , then you may also buy: WOODEN PICTURE FRAME WHITE FINISH. (Support: 0.01, Confidence: 0.62, Lift: 14.61)
#  - If you buy: WHITE HANGING HEART T-LIGHT HOLDER, then you may also buy: WOODEN PICTURE FRAME WHITE FINISH, WOODEN FRAME ANTIQUE WHITE . (Support: 0.01, Confidence: 0.09, Lift: 3.16)
#
# Checking recommendations for: WHITE METAL LANTERN
# Products recommended for 'WHITE METAL LANTERN': No recommendations found for 'WHITE METAL LANTERN'.
# No rules found for 'WHITE METAL LANTERN'.
#
# Checking recommendations for: CREAM CUPID HEARTS COAT HANGER
# Products recommended for 'CREAM CUPID HEARTS COAT HANGER': ['WHITE HANGING HEART T-LIGHT HOLDER']
# Rules for 'CREAM CUPID HEARTS COAT HANGER':
#  - If you buy: CREAM CUPID HEARTS COAT HANGER, then you may also buy: WHITE HANGING HEART T-LIGHT HOLDER. (Support: 0.01, Confidence: 0.44, Lift: 2.83)
#
# Checking recommendations for: EDWARDIAN PARASOL RED
# Products recommended for 'EDWARDIAN PARASOL RED': ['EDWARDIAN PARASOL BLACK', 'EDWARDIAN PARASOL NATURAL']
# Rules for 'EDWARDIAN PARASOL RED':
#  - If you buy: EDWARDIAN PARASOL RED, then you may also buy: EDWARDIAN PARASOL BLACK. (Support: 0.01, Confidence: 0.70, Lift: 26.31)
#  - If you buy: EDWARDIAN PARASOL RED, then you may also buy: EDWARDIAN PARASOL NATURAL. (Support: 0.01, Confidence: 0.54, Lift: 20.74)
#
# Checking recommendations for: RETRO COFFEE MUGS ASSORTED
# Products recommended for 'RETRO COFFEE MUGS ASSORTED': No recommendations found for 'RETRO COFFEE MUGS ASSORTED'.
# No rules found for 'RETRO COFFEE MUGS ASSORTED'.
#
# Checking recommendations for: SAVE THE PLANET MUG
# Products recommended for 'SAVE THE PLANET MUG': No recommendations found for 'SAVE THE PLANET MUG'.
# No rules found for 'SAVE THE PLANET MUG'.
#
# Checking recommendations for: VINTAGE BILLBOARD DRINK ME MUG
# Products recommended for 'VINTAGE BILLBOARD DRINK ME MUG': No recommendations found for 'VINTAGE BILLBOARD DRINK ME MUG'.
# No rules found for 'VINTAGE BILLBOARD DRINK ME MUG'.
#
# Checking recommendations for: VINTAGE BILLBOARD LOVE/HATE MUG
# Products recommended for 'VINTAGE BILLBOARD LOVE/HATE MUG': No recommendations found for 'VINTAGE BILLBOARD LOVE/HATE MUG'.
# No rules found for 'VINTAGE BILLBOARD LOVE/HATE MUG'.
#
# Checking recommendations for: WOOD 2 DRAWER CABINET WHITE FINISH
# Products recommended for 'WOOD 2 DRAWER CABINET WHITE FINISH': ['WHITE HANGING HEART T-LIGHT HOLDER', 'WOOD S/3 CABINET ANT WHITE FINISH', 'WOODEN FRAME ANTIQUE WHITE ', 'WOODEN PICTURE FRAME WHITE FINISH', 'WOODEN FRAME ANTIQUE WHITE ', 'WOOD S/3 CABINET ANT WHITE FINISH', 'WOOD S/3 CABINET ANT WHITE FINISH', 'WOODEN PICTURE FRAME WHITE FINISH', 'WOOD S/3 CABINET ANT WHITE FINISH', 'WOOD S/3 CABINET ANT WHITE FINISH', 'WOODEN FRAME ANTIQUE WHITE ', 'WOODEN PICTURE FRAME WHITE FINISH', 'WOODEN PICTURE FRAME WHITE FINISH']
# Rules for 'WOOD 2 DRAWER CABINET WHITE FINISH':
#  - If you buy: WOOD 2 DRAWER CABINET WHITE FINISH, then you may also buy: WHITE HANGING HEART T-LIGHT HOLDER. (Support: 0.01, Confidence: 0.47, Lift: 2.98)
#  - If you buy: WOOD 2 DRAWER CABINET WHITE FINISH, then you may also buy: WOOD S/3 CABINET ANT WHITE FINISH. (Support: 0.02, Confidence: 0.61, Lift: 17.58)
#  - If you buy: WOOD 2 DRAWER CABINET WHITE FINISH, then you may also buy: WOODEN FRAME ANTIQUE WHITE . (Support: 0.02, Confidence: 0.51, Lift: 9.73)
#  - If you buy: WOOD 2 DRAWER CABINET WHITE FINISH, then you may also buy: WOODEN PICTURE FRAME WHITE FINISH. (Support: 0.01, Confidence: 0.48, Lift: 11.24)
#  - If you buy: WOOD S/3 CABINET ANT WHITE FINISH, WOOD 2 DRAWER CABINET WHITE FINISH, then you may also buy: WOODEN FRAME ANTIQUE WHITE . (Support: 0.01, Confidence: 0.63, Lift: 12.08)
#  - If you buy: WOOD 2 DRAWER CABINET WHITE FINISH, WOODEN FRAME ANTIQUE WHITE , then you may also buy: WOOD S/3 CABINET ANT WHITE FINISH. (Support: 0.01, Confidence: 0.75, Lift: 21.83)
#  - If you buy: WOOD 2 DRAWER CABINET WHITE FINISH, then you may also buy: WOOD S/3 CABINET ANT WHITE FINISH, WOODEN FRAME ANTIQUE WHITE . (Support: 0.01, Confidence: 0.39, Lift: 23.59)
#  - If you buy: WOOD S/3 CABINET ANT WHITE FINISH, WOOD 2 DRAWER CABINET WHITE FINISH, then you may also buy: WOODEN PICTURE FRAME WHITE FINISH. (Support: 0.01, Confidence: 0.59, Lift: 13.84)
#  - If you buy: WOODEN PICTURE FRAME WHITE FINISH, WOOD 2 DRAWER CABINET WHITE FINISH, then you may also buy: WOOD S/3 CABINET ANT WHITE FINISH. (Support: 0.01, Confidence: 0.75, Lift: 21.65)
#  - If you buy: WOOD 2 DRAWER CABINET WHITE FINISH, then you may also buy: WOOD S/3 CABINET ANT WHITE FINISH, WOODEN PICTURE FRAME WHITE FINISH. (Support: 0.01, Confidence: 0.36, Lift: 26.36)
#  - If you buy: WOODEN PICTURE FRAME WHITE FINISH, WOOD 2 DRAWER CABINET WHITE FINISH, then you may also buy: WOODEN FRAME ANTIQUE WHITE . (Support: 0.01, Confidence: 0.83, Lift: 15.89)
#  - If you buy: WOOD 2 DRAWER CABINET WHITE FINISH, WOODEN FRAME ANTIQUE WHITE , then you may also buy: WOODEN PICTURE FRAME WHITE FINISH. (Support: 0.01, Confidence: 0.78, Lift: 18.35)
#  - If you buy: WOOD 2 DRAWER CABINET WHITE FINISH, then you may also buy: WOODEN PICTURE FRAME WHITE FINISH, WOODEN FRAME ANTIQUE WHITE . (Support: 0.01, Confidence: 0.40, Lift: 13.85)
#
# Checking recommendations for: WOOD S/3 CABINET ANT WHITE FINISH
# Products recommended for 'WOOD S/3 CABINET ANT WHITE FINISH': ['WHITE HANGING HEART T-LIGHT HOLDER', 'WOOD 2 DRAWER CABINET WHITE FINISH', 'WOODEN FRAME ANTIQUE WHITE ', 'WOODEN PICTURE FRAME WHITE FINISH', 'WOODEN FRAME ANTIQUE WHITE ', 'WOOD 2 DRAWER CABINET WHITE FINISH', 'WOOD 2 DRAWER CABINET WHITE FINISH', 'WOOD 2 DRAWER CABINET WHITE FINISH', 'WOODEN PICTURE FRAME WHITE FINISH', 'WOODEN PICTURE FRAME WHITE FINISH', 'WOODEN FRAME ANTIQUE WHITE ', 'WOODEN PICTURE FRAME WHITE FINISH', 'WOODEN PICTURE FRAME WHITE FINISH']
# Rules for 'WOOD S/3 CABINET ANT WHITE FINISH':
#  - If you buy: WOOD S/3 CABINET ANT WHITE FINISH, then you may also buy: WHITE HANGING HEART T-LIGHT HOLDER. (Support: 0.01, Confidence: 0.43, Lift: 2.73)
#  - If you buy: WOOD S/3 CABINET ANT WHITE FINISH, then you may also buy: WOOD 2 DRAWER CABINET WHITE FINISH. (Support: 0.02, Confidence: 0.53, Lift: 17.58)
#  - If you buy: WOOD S/3 CABINET ANT WHITE FINISH, then you may also buy: WOODEN FRAME ANTIQUE WHITE . (Support: 0.02, Confidence: 0.47, Lift: 9.01)
#  - If you buy: WOOD S/3 CABINET ANT WHITE FINISH, then you may also buy: WOODEN PICTURE FRAME WHITE FINISH. (Support: 0.01, Confidence: 0.39, Lift: 9.23)
#  - If you buy: WOOD S/3 CABINET ANT WHITE FINISH, WOOD 2 DRAWER CABINET WHITE FINISH, then you may also buy: WOODEN FRAME ANTIQUE WHITE . (Support: 0.01, Confidence: 0.63, Lift: 12.08)
#  - If you buy: WOOD S/3 CABINET ANT WHITE FINISH, WOODEN FRAME ANTIQUE WHITE , then you may also buy: WOOD 2 DRAWER CABINET WHITE FINISH. (Support: 0.01, Confidence: 0.71, Lift: 23.59)
#  - If you buy: WOOD S/3 CABINET ANT WHITE FINISH, then you may also buy: WOOD 2 DRAWER CABINET WHITE FINISH, WOODEN FRAME ANTIQUE WHITE . (Support: 0.01, Confidence: 0.34, Lift: 21.83)
#  - If you buy: WOOD S/3 CABINET ANT WHITE FINISH, WOODEN PICTURE FRAME WHITE FINISH, then you may also buy: WOOD 2 DRAWER CABINET WHITE FINISH. (Support: 0.01, Confidence: 0.80, Lift: 26.36)
#  - If you buy: WOOD S/3 CABINET ANT WHITE FINISH, WOOD 2 DRAWER CABINET WHITE FINISH, then you may also buy: WOODEN PICTURE FRAME WHITE FINISH. (Support: 0.01, Confidence: 0.59, Lift: 13.84)
#  - If you buy: WOOD S/3 CABINET ANT WHITE FINISH, then you may also buy: WOODEN PICTURE FRAME WHITE FINISH, WOOD 2 DRAWER CABINET WHITE FINISH. (Support: 0.01, Confidence: 0.31, Lift: 21.65)
#  - If you buy: WOOD S/3 CABINET ANT WHITE FINISH, WOODEN PICTURE FRAME WHITE FINISH, then you may also buy: WOODEN FRAME ANTIQUE WHITE . (Support: 0.01, Confidence: 0.86, Lift: 16.34)
#  - If you buy: WOOD S/3 CABINET ANT WHITE FINISH, WOODEN FRAME ANTIQUE WHITE , then you may also buy: WOODEN PICTURE FRAME WHITE FINISH. (Support: 0.01, Confidence: 0.71, Lift: 16.76)
#  - If you buy: WOOD S/3 CABINET ANT WHITE FINISH, then you may also buy: WOODEN PICTURE FRAME WHITE FINISH, WOODEN FRAME ANTIQUE WHITE . (Support: 0.01, Confidence: 0.34, Lift: 11.70)
#
# Checking recommendations for: WOODEN PICTURE FRAME WHITE FINISH
# Products recommended for 'WOODEN PICTURE FRAME WHITE FINISH': ['WHITE HANGING HEART T-LIGHT HOLDER', 'WOOD 2 DRAWER CABINET WHITE FINISH', 'WOOD S/3 CABINET ANT WHITE FINISH', 'WOODEN FRAME ANTIQUE WHITE ', 'WOODEN FRAME ANTIQUE WHITE ', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WHITE HANGING HEART T-LIGHT HOLDER', 'WOOD 2 DRAWER CABINET WHITE FINISH', 'WOOD S/3 CABINET ANT WHITE FINISH', 'WOOD S/3 CABINET ANT WHITE FINISH', 'WOODEN FRAME ANTIQUE WHITE ', 'WOOD 2 DRAWER CABINET WHITE FINISH', 'WOOD 2 DRAWER CABINET WHITE FINISH', 'WOODEN FRAME ANTIQUE WHITE ', 'WOOD S/3 CABINET ANT WHITE FINISH', 'WOOD S/3 CABINET ANT WHITE FINISH']
# Rules for 'WOODEN PICTURE FRAME WHITE FINISH':
#  - If you buy: WOODEN PICTURE FRAME WHITE FINISH, then you may also buy: WHITE HANGING HEART T-LIGHT HOLDER. (Support: 0.02, Confidence: 0.47, Lift: 2.98)
#  - If you buy: WOODEN PICTURE FRAME WHITE FINISH, then you may also buy: WOOD 2 DRAWER CABINET WHITE FINISH. (Support: 0.01, Confidence: 0.34, Lift: 11.24)
#  - If you buy: WOODEN PICTURE FRAME WHITE FINISH, then you may also buy: WOOD S/3 CABINET ANT WHITE FINISH. (Support: 0.01, Confidence: 0.32, Lift: 9.23)
#  - If you buy: WOODEN PICTURE FRAME WHITE FINISH, then you may also buy: WOODEN FRAME ANTIQUE WHITE . (Support: 0.03, Confidence: 0.68, Lift: 12.90)
#  - If you buy: WOODEN PICTURE FRAME WHITE FINISH, WHITE HANGING HEART T-LIGHT HOLDER, then you may also buy: WOODEN FRAME ANTIQUE WHITE . (Support: 0.01, Confidence: 0.72, Lift: 13.67)
#  - If you buy: WOODEN PICTURE FRAME WHITE FINISH, WOODEN FRAME ANTIQUE WHITE , then you may also buy: WHITE HANGING HEART T-LIGHT HOLDER. (Support: 0.01, Confidence: 0.50, Lift: 3.16)
#  - If you buy: WOODEN PICTURE FRAME WHITE FINISH, then you may also buy: WHITE HANGING HEART T-LIGHT HOLDER, WOODEN FRAME ANTIQUE WHITE . (Support: 0.01, Confidence: 0.34, Lift: 14.61)
#  - If you buy: WOOD S/3 CABINET ANT WHITE FINISH, WOODEN PICTURE FRAME WHITE FINISH, then you may also buy: WOOD 2 DRAWER CABINET WHITE FINISH. (Support: 0.01, Confidence: 0.80, Lift: 26.36)
#  - If you buy: WOODEN PICTURE FRAME WHITE FINISH, WOOD 2 DRAWER CABINET WHITE FINISH, then you may also buy: WOOD S/3 CABINET ANT WHITE FINISH. (Support: 0.01, Confidence: 0.75, Lift: 21.65)
#  - If you buy: WOODEN PICTURE FRAME WHITE FINISH, then you may also buy: WOOD S/3 CABINET ANT WHITE FINISH, WOOD 2 DRAWER CABINET WHITE FINISH. (Support: 0.01, Confidence: 0.25, Lift: 13.84)
#  - If you buy: WOODEN PICTURE FRAME WHITE FINISH, WOOD 2 DRAWER CABINET WHITE FINISH, then you may also buy: WOODEN FRAME ANTIQUE WHITE . (Support: 0.01, Confidence: 0.83, Lift: 15.89)
#  - If you buy: WOODEN PICTURE FRAME WHITE FINISH, WOODEN FRAME ANTIQUE WHITE , then you may also buy: WOOD 2 DRAWER CABINET WHITE FINISH. (Support: 0.01, Confidence: 0.42, Lift: 13.85)
#  - If you buy: WOODEN PICTURE FRAME WHITE FINISH, then you may also buy: WOOD 2 DRAWER CABINET WHITE FINISH, WOODEN FRAME ANTIQUE WHITE . (Support: 0.01, Confidence: 0.28, Lift: 18.35)
#  - If you buy: WOOD S/3 CABINET ANT WHITE FINISH, WOODEN PICTURE FRAME WHITE FINISH, then you may also buy: WOODEN FRAME ANTIQUE WHITE . (Support: 0.01, Confidence: 0.86, Lift: 16.34)
#  - If you buy: WOODEN PICTURE FRAME WHITE FINISH, WOODEN FRAME ANTIQUE WHITE , then you may also buy: WOOD S/3 CABINET ANT WHITE FINISH. (Support: 0.01, Confidence: 0.40, Lift: 11.70)
#  - If you buy: WOODEN PICTURE FRAME WHITE FINISH, then you may also buy: WOOD S/3 CABINET ANT WHITE FINISH, WOODEN FRAME ANTIQUE WHITE . (Support: 0.01, Confidence: 0.27, Lift: 16.76)
